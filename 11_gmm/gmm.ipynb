# %%
import pandas as pd

# %%
mixed_population_df = pd.read_csv('Mixed_population_Data.csv')

# %%
mixed_population_df
# Out:
#      The_Data
# 0      113.56
# 1       61.05
# 2       37.02
# 3      108.99
# 4      110.36
# ..        ...
# 977    117.43
# 978     64.23
# 979    107.29
# 980    117.62
# 981    105.64
#
# [982 rows x 1 columns]

# %%
mixed_population_df.describe()
# Out:
#          The_Data
# count  982.000000
# mean    80.265438
# std     34.307295
# min     -5.150000
# 25%     49.980000
# 50%     84.825000
# 75%    110.805000
# max    147.660000

# %%
mixed_population_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
number_of_samples = 2000
sample_mean = -5
sample_sd = 0.7

# %%
import numpy as np

sample_data = np.random.normal(sample_mean, sample_sd, number_of_samples)

# %%
pd.DataFrame(sample_data).plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
sns.kdeplot(data=sample_data)
# Out:
# <Axes: ylabel='Density'>

# %%
sample_data2 = np.random.normal(1, 0.3, number_of_samples)

# %%
sns.kdeplot(data=[sample_data, sample_data2])
# Out:
# <Axes: ylabel='Density'>

# %%
sample_data = np.random.normal(45, 17, 480)
sample_data2 = np.random.normal(110, 18, 600)
combined_samples = np.concatenate([sample_data, sample_data2])
sns.kdeplot(data=[combined_samples, mixed_population_df["The_Data"]])
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.mixture import GaussianMixture

gmm = GaussianMixture(n_components=2, covariance_type='full', tol=0.001)
gmm = gmm.fit(combined_samples.reshape(-1, 1))

# %%
gmm.means_
# Out:
# array([[110.25888838],
#        [ 45.4261443 ]])

# %%
np.sqrt(gmm.covariances_)
# Out:
# array([[[17.43431763]],
#
#        [[17.03641721]]])
