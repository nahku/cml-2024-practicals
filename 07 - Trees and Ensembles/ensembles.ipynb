# %%
import pandas as pd

# %%
input_df = pd.read_csv("diabetes.csv")

# %%
input_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import seaborn as sns

sns.countplot(x='Outcome', data=input_df)
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x='Pregnancies', data=input_df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
sns.countplot(x='Age', data=input_df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
input_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import numpy as np
input_df[["BloodPressure", "SkinThickness", "Insulin", "BMI", "Glucose"]] = input_df[["BloodPressure", "SkinThickness", "Insulin", "BMI", "Glucose"]].replace(0, np.nan)

# %%
input_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
input_df["BloodPressure"].fillna(input_df["BloodPressure"].mean(), inplace=True)
input_df["SkinThickness"].fillna(input_df["SkinThickness"].mean(), inplace=True)
input_df["Insulin"].fillna(input_df["Insulin"].mean(), inplace=True)
input_df["BMI"].fillna(input_df["BMI"].mean(), inplace=True)
input_df["Glucose"].fillna(input_df["Glucose"].mean(), inplace=True)

# %%
input_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
pd.plotting.scatter_matrix(input_df, alpha=0.2)
# Out:
# array([[<Axes: xlabel='Pregnancies', ylabel='Pregnancies'>,
#         <Axes: xlabel='Glucose', ylabel='Pregnancies'>,
#         <Axes: xlabel='BloodPressure', ylabel='Pregnancies'>,
#         <Axes: xlabel='SkinThickness', ylabel='Pregnancies'>,
#         <Axes: xlabel='Insulin', ylabel='Pregnancies'>,
#         <Axes: xlabel='BMI', ylabel='Pregnancies'>,
#         <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Pregnancies'>,
#         <Axes: xlabel='Age', ylabel='Pregnancies'>,
#         <Axes: xlabel='Outcome', ylabel='Pregnancies'>],
#        [<Axes: xlabel='Pregnancies', ylabel='Glucose'>,
#         <Axes: xlabel='Glucose', ylabel='Glucose'>,
#         <Axes: xlabel='BloodPressure', ylabel='Glucose'>,
#         <Axes: xlabel='SkinThickness', ylabel='Glucose'>,
#         <Axes: xlabel='Insulin', ylabel='Glucose'>,
#         <Axes: xlabel='BMI', ylabel='Glucose'>,
#         <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Glucose'>,
# ...

# %%
sns.heatmap(input_df.select_dtypes(exclude="object").corr().abs(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
x = input_df.drop("Outcome", axis=1)
y = input_df["Outcome"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=3, random_state=0)
model = model.fit(x_train, y_train)

# %%
from matplotlib import pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
plot_tree(model, filled=True, feature_names=x.columns, class_names=["diabetes", "healthy"])
plt.show()

# %%
model = DecisionTreeClassifier(max_depth=6, random_state=0, ccp_alpha=0.01)
model = model.fit(x_train, y_train)

# %%
plt.figure(figsize=(20, 20))
plot_tree(model, filled=True, feature_names=x.columns, class_names=["diabetes", "healthy"])
plt.show()

# %%
# typo forest


from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model = model.fit(x_train, y_train)

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7532467532467533

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = { "ccp_alpha": [0.001, 0.01, 0.1, 1, 10, 100],
               "criterion": ["gini", "entropy"],
               "max_depth": [3, 5, 7, 9, 11],
               "max_leaf_nodes": [3, 5, 7, 9, 11],
               }

clf = GridSearchCV(RandomForestClassifier(), param_grid)
best_model = clf.fit(x_train, y_train)

# %%
predictions = best_model.predict(x_test)
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot()
